# %%
import  pandas  as pd

# %%
import seaborn as s

# %%
s.set(color_codes=True)

# %%
we=pd.read_csv('D:/in/Horror movies.csv')

# %%
we.head()
# Out:
#    Rank                                   Film Worldwide gross  Year      Ref
# 0     1                                     It    $702,781,748  2017   [1][2]
# 1     2                        The Sixth Sense    $672,806,292  1999   [3][4]
# 2     3                            I Am Legend    $585,532,684  2007   [5][6]
# 3     4                            World War Z    $540,007,876  2013   [7][8]
# 4     5  Hotel Transylvania 3: Summer Vacation    $528,583,774  2018  [9][10]

# %%
we.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             50 non-null     int64
#  1   Film             50 non-null     object
#  2   Worldwide gross  50 non-null     object
#  3   Year             50 non-null     int64
#  4   Ref              50 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 2.1+ KB

# %%
s.barplot(x='Year',y='Rank',data=we)
# Out:
# <Axes: xlabel='Year', ylabel='Rank'>

# %%
s.lineplot(we['Rank'])
# Out:
# <Axes: ylabel='Rank'>

# %%
s.scatterplot(x='Film',y='Year',data=we)
# Out:
# <Axes: xlabel='Film', ylabel='Year'>
